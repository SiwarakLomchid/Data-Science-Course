# %% [markdown]
# # Similarity the capital city in the world

# %% [markdown]
# ## Introduction

# %% [markdown]
# There are about 244 countries in the world. The capital city of those countries is all the same as they are the heart of the country. However, Each city have their own characteristic. The question is can we do clustering for those capital cities? can we group those capital city?

# %% [markdown]
# If we can group similar cities to each other, a business model which is success in a certain city might also be success if we implement it in the similar city in the other country

# %% [markdown]
# Characteristic of the city should be able to be identified by using similarity of the venues located in the center of the city. With this assumption if we use the data containting category of venues nearby the center of the city that we can get it from Foursquare location data, we should be able to do clustering for the cities.

# %% [markdown]
# Also, can we use population data to make data visualization for some information display?

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Folium installed
# Libraries imported.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# <Response [200]>

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#          Country    Capital   Latitude  Longitude
# 0       Abkhazia    Sukhumi  43.001525  41.023415
# 1    Afghanistan      Kabul  34.575503  69.240073
# 2  Aland Islands  Mariehamn       60.1  19.933333
# 3        Albania     Tirana  41.327546  19.818698
# 4        Algeria    Algiers  36.752887   3.042048

# %%
# create map
# Center of the world map is Latitude = 40.866667, Longitude = 34.566667
# Credit https://en.wikipedia.org/wiki/Geographical_centre_of_Earth
latitude = '40.866667'
longitude = '34.566667'
map_ori = folium.Map(location = [latitude, longitude], zoom_start = 2)

for lat, lng, city, country in zip(df_cor['Latitude'], df_cor['Longitude'], df_cor['Capital'], df_cor['Country']):
    label = '{}, {}'.format(city, country)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_ori) 
map_ori
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Data section

# %% [markdown]
# In order to solve the problem mentioned in the introduction session, we need to have the data set which includes the data of country name, capital name, population, cordinates of the capital cities.

# %% [markdown]
# Luckily, there are available data in the internet but not all the required data are available in a single data source. Therefore, we need to pull the data from a couple of data sources and process it to be ready for solving our business problem.

# %% [markdown]
# ### Country name, capital name and population from wikipedia.org
# https://en.wikipedia.org/wiki/List_of_national_capitals_by_population

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# (244, 6)

# %%
df_pop['Population'] = df_pop['Population'].astype(int)
df_pop.sort_values('Rank', axis = 0, ascending = True, inplace = True)
df_pop.head()
# Out:
#     Rank       Country/Territory        Capital  Population  Year  \
# 15     -               Hong Kong      Hong Kong     7482500  2018
# 0      1                China PR        Beijing    21542000  2010
# 9     10  United Kingdom England         London     8908081  2015
# 100  100                  Israel  Jerusalem[50]      780200
# 101  101                 Nigeria          Abuja      778567  [52]
#
#     % ofcountry'spopulation
# 15                     100%
# 0                      1.5%
# 9                    13.19%
# 100                   9.68%
# 101                   0.45%

# %% [markdown]
# ### Country name, capital name and its cordinates are available in provided webpage.
# https://www.jasom.net/list-of-capital-cities-with-latitude-and-longitude/

# %%
df_cor.head()
# Out:
#          Country    Capital   Latitude  Longitude
# 0       Abkhazia    Sukhumi  43.001525  41.023415
# 1    Afghanistan      Kabul  34.575503  69.240073
# 2  Aland Islands  Mariehamn       60.1  19.933333
# 3        Albania     Tirana  41.327546  19.818698
# 4        Algeria    Algiers  36.752887   3.042048

# %% [markdown]
# With the accessible data sources, we can process the data and get answer of the business problem.
# After all data are ready, we can make data visualization to report the project.
